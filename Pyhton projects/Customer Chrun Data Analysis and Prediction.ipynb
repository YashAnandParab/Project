# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df=pd.read_csv('telecom_churn.csv')

# %%
df.head()
# Out:
#   state  account length  area code phone number international plan  \
# 0    KS             128        415     382-4657                 no
# 1    OH             107        415     371-7191                 no
# 2    NJ             137        415     358-1921                 no
# 3    OH              84        408     375-9999                yes
# 4    OK              75        415     330-6626                yes
#
#   voice mail plan  number vmail messages  total day minutes  total day calls  \
# 0             yes                     25              265.1              110
# 1             yes                     26              161.6              123
# 2              no                      0              243.4              114
# 3              no                      0              299.4               71
# 4              no                      0              166.7              113
#
#    total day charge  ...  total eve calls  total eve charge  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3333 entries, 0 to 3332
# Data columns (total 21 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   state                   3333 non-null   object
#  1   account length          3333 non-null   int64
#  2   area code               3333 non-null   int64
#  3   phone number            3333 non-null   object
#  4   international plan      3333 non-null   object
#  5   voice mail plan         3333 non-null   object
#  6   number vmail messages   3333 non-null   int64
#  7   total day minutes       3333 non-null   float64
#  8   total day calls         3333 non-null   int64
#  9   total day charge        3333 non-null   float64
#  10  total eve minutes       3333 non-null   float64
#  11  total eve calls         3333 non-null   int64
#  12  total eve charge        3333 non-null   float64
#  13  total night minutes     3333 non-null   float64
# ...

# %%
df.isnull().sum()
# Out:
# state                     0
# account length            0
# area code                 0
# phone number              0
# international plan        0
# voice mail plan           0
# number vmail messages     0
# total day minutes         0
# total day calls           0
# total day charge          0
# total eve minutes         0
# total eve calls           0
# total eve charge          0
# total night minutes       0
# total night calls         0
# total night charge        0
# total intl minutes        0
# total intl calls          0
# total intl charge         0
# customer service calls    0
# churn                     0
# dtype: int64

# %%
df.describe()
# Out:
#        account length    area code  number vmail messages  total day minutes  \
# count     3333.000000  3333.000000            3333.000000        3333.000000
# mean       101.064806   437.182418               8.099010         179.775098
# std         39.822106    42.371290              13.688365          54.467389
# min          1.000000   408.000000               0.000000           0.000000
# 25%         74.000000   408.000000               0.000000         143.700000
# 50%        101.000000   415.000000               0.000000         179.400000
# 75%        127.000000   510.000000              20.000000         216.400000
# max        243.000000   510.000000              51.000000         350.800000
#
#        total day calls  total day charge  total eve minutes  total eve calls  \
# count      3333.000000       3333.000000        3333.000000      3333.000000
# mean        100.435644         30.562307         200.980348       100.114311
# ...

# %% [markdown]
# The frequence of the calls is higher during working hours but the amount time spend on a call is still lower than that of night. It tells us that people talk for a longer time during night.

# %%
plt.title('Total Day Minutes')
plt.hist(df['total day minutes'], bins = 100)
plt.show()
plt.title('Total Eve Minutes')
plt.hist(df['total eve minutes'], bins = 100)
plt.show()
plt.title('Total Night Minutes')
plt.hist(df['total night minutes'], bins = 100)
plt.show()

# %%
# To find the total number of customers who have chruned?
df['churn'].value_counts()
# Out:
# churn
# False    2850
# True      483
# Name: count, dtype: int64

# %% [markdown]
# So the total number of customers who have chruned is 483

# %%
sns.countplot(data=df,x='churn',hue='churn')
plt.show()

# %%
# To find the customers who have chruned made more or less customer service calls?
df.groupby(by='churn')['customer service calls'].mean()
# Out:
# churn
# False    1.449825
# True     2.229814
# Name: customer service calls, dtype: float64

# %% [markdown]
# Since the mean of true value is more the customers who have chruned have made more customer service calls

# %%
sns.boxplot(x = 'churn',y = 'customer service calls',data = df,hue = "international plan")
plt.show()

# %%
# To find the customers who have chruned have high number of international plan or not?
df.groupby(by='churn')['international plan'].value_counts()
# Out:
# churn  international plan
# False  no                    2664
#        yes                    186
# True   no                     346
#        yes                    137
# Name: count, dtype: int64

# %%
# To find out if one State has more churners compared to another.
plt.figure(figsize=(16,8))
sns.countplot(data=df,x='state',hue='churn')
plt.show()

# %%
df.groupby(by='state')['customer service calls'].sum().nlargest(5)
# Out:
# state
# WV    159
# NY    142
# OR    135
# MN    130
# VT    127
# Name: customer service calls, dtype: int64

# %% [markdown]
# So by the above chart we found out that CA was our worst performing state which
# has the lowest number of user and west virgina is  our best performing state.
# but also it has the most amount of customer service calls which if left us checked
# could result in high amount of churnes.

# %%
new_df=df.drop(columns=['state','account length','area code','phone number','international plan','voice mail plan'], axis=1)

# %%
plt.figure(figsize=(18,6))
sns.heatmap(new_df.corr(),annot=True,vmin=-1,vmax=1,cmap='coolwarm')
plt.show()

# %%
cat_col=df.select_dtypes(include='object').columns.tolist()
num_col=df.select_dtypes(include='number').columns.tolist()

# %%
df=pd.get_dummies(df,columns=cat_col,dtype=int,drop_first=True)

# %%
X=df.drop(columns=['account length','churn'],axis=1)
y=df['churn']

# %%
from sklearn.model_selection import train_test_split

# %%
 X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=42,stratify=y)

# %%
# !pip install lazypredict
# Out:
# ...
#    ---------------------------------------- 0.0/1.4 MB ? eta -:--:--
#    --- ------------------------------------ 0.1/1.4 MB 4.2 MB/s eta 0:00:01
#    --------- ------------------------------ 0.3/1.4 MB 4.1 MB/s eta 0:00:01
#    --------------- ------------------------ 0.6/1.4 MB 4.3 MB/s eta 0:00:01
#    ---------------------- ----------------- 0.8/1.4 MB 4.6 MB/s eta 0:00:01
#    -------------------------- ------------- 1.0/1.4 MB 4.4 MB/s eta 0:00:01
#    -------------------------------- ------- 1.2/1.4 MB 4.4 MB/s eta 0:00:01
#    -------------------------------------- - 1.4/1.4 MB 4.4 MB/s eta 0:00:01
#    ---------------------------------------- 1.4/1.4 MB 4.2 MB/s eta 0:00:00
# ...

# %%
from lazypredict.Supervised import LazyClassifier

# %%
clf = LazyClassifier(ignore_warnings=True)
models,predictions = clf.fit(X_train, X_test, y_train, y_test)
print(models)
# Out:
#  97%|███████████████████████████████████████████████████████████████████████████████▏  | 28/29 [02:24<00:07,  7.39s/it]
# [LightGBM] [Info] Number of positive: 324, number of negative: 1909
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.002067 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 2346
# [LightGBM] [Info] Number of data points in the train set: 2233, number of used features: 67
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.145096 -> initscore=-1.773591
# [LightGBM] [Info] Start training from score -1.773591
# 100%|██████████████████████████████████████████████████████████████████████████████████| 29/29 [02:26<00:00,  5.04s/it]
#                                Accuracy  Balanced Accuracy  ROC AUC  F1 Score  \
# Model
# XGBClassifier                      0.95               0.87     0.87      0.95
# ...

# %%
models.sort_values('Accuracy',ascending=False)
# Out:
#                                Accuracy  Balanced Accuracy  ROC AUC  F1 Score  \
# Model
# XGBClassifier                      0.95               0.87     0.87      0.95
# LGBMClassifier                     0.95               0.87     0.87      0.95
# BaggingClassifier                  0.94               0.84     0.84      0.94
# DecisionTreeClassifier             0.93               0.82     0.82      0.93
# RandomForestClassifier             0.90               0.64     0.64      0.87
# ExtraTreesClassifier               0.88               0.57     0.57      0.83
# NearestCentroid                    0.87               0.58     0.58      0.83
# AdaBoostClassifier                 0.87               0.66     0.66      0.85
# KNeighborsClassifier               0.86               0.53     0.53      0.81
# PassiveAggressiveClassifier        0.86               0.51     0.51      0.79
# LinearDiscriminantAnalysis         0.86               0.50     0.50      0.79
# ...

# %%
from xgboost import XGBClassifier

# %%
xgb=XGBClassifier()

# %%
xgb.fit(X_train,y_train)
# Out:
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, device=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               gamma=None, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=None, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=None, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               multi_strategy=None, n_estimators=None, n_jobs=None,
#               num_parallel_tree=None, random_state=None, ...)

# %%
xgb_pred=xgb.predict(X_test)

# %%
from sklearn.metrics import classification_report

# %%
print(classification_report(y_test,xgb_pred))
# Out:
#               precision    recall  f1-score   support
#
#        False       0.96      0.99      0.97       941
#         True       0.90      0.76      0.83       159
#
#     accuracy                           0.95      1100
#    macro avg       0.93      0.87      0.90      1100
# weighted avg       0.95      0.95      0.95      1100
